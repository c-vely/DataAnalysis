# %% [markdown]
# # 웹 브라우저 자동화 (selenium)

# %%
# 라이브러리 선언
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
# 드라이버 위치 설정 (상대)
driver_loc = "../extern\chromedriver/chromedriver.exe"

# %%
# 드라이버 옵션 설정
options = webdriver.ChromeOptions()

# %%
options.add_argument("window-size = 1920x1080")

# %%
# 웹 드라이버 정의
driver = webdriver.Chrome(driver_loc, options = options)
# Out:
# C:\Users\PC17\AppData\Local\Temp\ipykernel_8540\532407389.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver_loc, options = options)

# %%
#웹 페이지 파싱 될때까지 최대 3초 기다림
driver.implicitly_wait(3)

# %% [markdown]
# ### 1. 웹페이지 이동

# %%
targetUrl = "https://www.google.com/"

driver.get(targetUrl)

# %%
print(driver.current_url)
# Out:
# https://www.google.com/

# %%
targetUrl = "https://www.sparkkorea.com/"

driver.get(targetUrl)

# %%
# 지금 url 정보 확인
print(driver.current_url)
# Out:
# https://sparkkorea.com/

# %%
# driver가 접속한 페이지 소스 가져오기
html = driver.page_source

# %%
import bs4

# %%
bsobj = bs4.BeautifulSoup(html, "html.parser")

# %%
bsobj
# Out:
# <html lang="ko-KR"><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://sparkkorea.com/xmlrpc.php" rel="pingback"/>
# <title>스파크 코리아 – 스파크코리아 자료공유</title>
# <meta content="max-image-preview:large" name="robots"/>
# <meta content="QRZVgHsoL23RuwmgmXNuXfO-mUaxCkdvhP2rRvLT270" name="google-site-verification"/>
# <!-- Async WordPress.com Remote Login -->
# <script id="wpcom_remote_login_js">
# var wpcom_remote_login_extra_auth = '';
# function wpcom_remote_login_remove_dom_node_id( element_id ) {
# 	var dom_node = document.getElementById( element_id );
# 	if ( dom_node ) { dom_node.parentNode.removeChild( dom_node ); }
# }
# function wpcom_remote_login_remove_dom_node_classes( class_name ) {
# 	var dom_nodes = document.querySelectorAll( '.' + class_name );
# 	for ( var i = 0; i < dom_nodes.length; i++ ) {
# ...

# %% [markdown]
# ### 2. 액션대상 요소 탐색

# %%
quizBtn = '//*[@id="menu-item-382"]/a'

# %%
driver.find_element(By.XPATH, quizBtn).click()

# %% [markdown]
# ###
# * 구글 서치바 테스트

# %%
googleUrl = "https://www.google.com/"

# %%
driver.get(googleUrl)

# %%
gooleSerchBar = '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input'

# %%
keywords = "selenium"

# %%
driver.find_element(By.XPATH, gooleSerchBar).send_keys(keywords)

# %%
driver.find_element(By.XPATH, gooleSerchBar).send_keys(Keys.ENTER)

# %%
# 셀레니움은 접속 용도로 쓰고, 이후 소스를 받아와서 데이터 수집하는 것이 중요함
html = driver.page_source

# %%
bsobj = bs4.BeautifulSoup(html, "html.parser")

# %%
bsobj.find(name="div")
# Out:
# <div id="wrapper" style="height: auto !important;">
# <div class="top-button">
# <div class="profile">
# <button type="button"><img alt="블로그 이미지" src="https://tistory1.daumcdn.net/tistory/4628042/attach/93ae12f06a0641aeb8fdf7e83edde503"/></button>
# <nav>
# <ul>
# <li><a href="https://gorokke.tistory.com/manage">관리</a></li>
# <li><a href="https://gorokke.tistory.com/manage/entry/post ">글쓰기</a></li>
# <li class="login"><a href="#">로그인</a></li>
# <li class="logout" style="display: none;"><a href="#">로그아웃</a></li>
# </ul>
# </nav>
# </div>
# <div class="menu">
# <button type="button"></button>
# </div>
# </div>
# <header>
# <div class="inner">
# <p>
# <a href="https://gorokke.tistory.com/">
#
#
# 									고로케
#
# 							</a>
# </p>
# <nav id="blog-menu">
# <ul>
# <li class="t_menu_home first"><a href="/" target="">홈</a></li>
# <li class="t_menu_tag last"><a href="/tag" target="">태그</a></li>
# </ul>
# </nav>
# </div>
# </header>
# <section style="z-index: 110; height: auto !important;">
# ...
